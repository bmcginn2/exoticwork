# %%
from re import A
import numpy as np
from IPython.display import clear_output
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
import matplotlib.pyplot as plt
from pprint import pprint
import time

class Node:
  def __init__(self, name, connect, connectr, io):
    self.name = name
    self.connect = connect
    self.connectr = connectr
    self.io = io

class States:
    def __init__(self, q, a, b, s):
        self.state = q
        self.a = a
        self.b = b
        self.s = s

    def __connectionAf__(self, e1, e2, n1, n2, w1, w2, s1, s2, X, Y):
        self.ae2 = e1
        self.ae1 = e2
        self.an2 = n1
        self.an1 = n2
        self.aw2 = w1
        self.aw1 = w2
        self.as2 = s1
        self.as1 = s2
        self.X = X
        self.Y = Y

    def __connectionBf__(self, e1, e2, n1, n2, w1, w2, s1, s2):
        self.be2 = e1
        self.be1 = e2
        self.bn2 = n1
        self.bn1 = n2
        self.bw2 = w1
        self.bw1 = w2
        self.bs2 = s1
        self.bs1 = s2

    def __connectionSf__(self, e1, e2, n1, n2, w1, w2, s1, s2):
        self.se2 = e1
        self.se1 = e2
        self.sn2 = n1
        self.sn1 = n2
        self.sw2 = w1
        self.sw1 = w2
        self.ss2 = s1
        self.ss1 = s2


    def __connectionAr__(self, e1, e2, n1, n2, w1, w2, s1, s2):
        self.e2 = e1
        self.e1 = e2
        self.n2 = n1
        self.n1 = n2
        self.w2 = w1
        self.w1 = w2
        self.s1 = s1
        self.s1 = s2

    def __connectionBr__(self, e1, e2, n1, n2, w1, w2, s1, s2):
        self.e2 = e1
        self.e1 = e2
        self.n2 = n1
        self.n1 = n2
        self.w2 = w1
        self.w1 = w2
        self.s1 = s1
        self.s1 = s2

    def __connectionSr__(self, e1, e2, n1, n2, w1, w2, s1, s2):
        self.e2 = e1
        self.e1 = e2
        self.n2 = n1
        self.n1 = n2
        self.w2 = w1
        self.w1 = w2
        self.s1 = s1
        self.s1 = s2

def plot(classy, token):
  fig = plt.figure()
  ax = fig.add_subplot(111)


  vq1 = matplotlib.patches.Rectangle((-350, -300), 200, 600, color ='white', ec = 'black')
  s1 = matplotlib.patches.Rectangle((-300, -250), 100, 100, color ='white', ec = 'black')
  b1 = matplotlib.patches.Rectangle((-300, -75),  100, 100, color ='white', ec = 'black')
  a1 = matplotlib.patches.Rectangle((-300, 100), 100, 100, color ='white', ec = 'black')

  vq2 = matplotlib.patches.Rectangle((-100, -300), 200, 600, color ='white', ec = 'black')
  s2 = matplotlib.patches.Rectangle((-50, -250), 100, 100, color ='white', ec = 'black')
  b2 = matplotlib.patches.Rectangle((-50, -75), 100, 100, color ='white', ec = 'black')
  a2 = matplotlib.patches.Rectangle((-50, 100), 100, 100, color ='white', ec = 'black')

  ax.add_patch(vq1)
  ax.add_patch(s1)
  ax.add_patch(b1)
  ax.add_patch(a1)
  ax.add_patch(vq2)
  ax.add_patch(s2)
  ax.add_patch(b2)
  ax.add_patch(a2)

  ball = matplotlib.patches.Circle(token, 10, color ='red')
  ax.add_patch(ball)

  if len(classy) >= 3:
    q3 = matplotlib.patches.Rectangle((150, -300), 200, 600,  color ='white', ec = 'black')
    s3 = matplotlib.patches.Rectangle((200, -250), 100, 100, color ='white', ec = 'black')
    b3 = matplotlib.patches.Rectangle((200, -75), 100, 100, color ='white', ec = 'black')
    a3 = matplotlib.patches.Rectangle((200, 100), 100, 100, color ='white', ec = 'black')

    ax.add_patch(q3)
    ax.add_patch(s3)
    ax.add_patch(b3)
    ax.add_patch(a3)

    if len(classy) >= 4:
      q4 = matplotlib.patches.Rectangle((400, -300), 200, 600,  color ='white', ec = 'black')
      s4 = matplotlib.patches.Rectangle((450, -250), 100, 100, color ='white', ec = 'black')
      b4 = matplotlib.patches.Rectangle((450, -75), 100, 100, color ='white', ec = 'black')
      a4 = matplotlib.patches.Rectangle((450, 100), 100, 100, color ='white', ec = 'black')

      ax.add_patch(q4)
      ax.add_patch(s4)
      ax.add_patch(b4)
      ax.add_patch(a4)

  xmin1, xmax1 = -290, -210
  ymin1, ymax1 = 110, 190
  x1 = -250

  for state in classy:
    y1 = 150
    if state.a == 1:
        plt.vlines(x=x1, ymin=ymin1, ymax=ymax1, colors='black')
    else:
        plt.hlines(y=y1, xmin=xmin1, xmax=xmax1, colors='black')
    y1 -= 175
    ymin1 -= 175
    ymax1 -= 175
    if state.b == 1:
        plt.vlines(x=x1, ymin=ymin1, ymax=ymax1, colors='black')
    else:
        plt.hlines(y=y1, xmin=xmin1, xmax=xmax1, colors='black')
    y1 -= 175
    ymin1 -= 175
    ymax1 -= 175
    if state.s == 1:
        plt.vlines(x=x1, ymin=ymin1, ymax=ymax1, colors='black')
    else:
        plt.hlines(y=y1, xmin=xmin1, xmax=xmax1, colors='black')
    x1 += 250
    xmin1 += 250
    xmax1 += 250
    ymin1 = 110
    ymax1 = 190
    y1 = 150

  plt.xlim([-400, 650])
  plt.ylim([-400, 400])

  plt.show()
  #plt.clf()

num_states = 2

q1=States('q1', 1,1,1)
q2=States('q2', 1,1,1)

#q1 and q2 connection nodes
q1.__connectionAf__(Node("q1.ae2", "q1.ae2", "q1.X", (-275, 125)), Node("q1.ae1", "q2.bw2", "q1.ae1", (-275, 175)), Node("q1.an2", "q1.an2", "q1.se1", (-275, 175)), Node("q1.an1", "q1.sw2", "q1.an1", (-225, 175)),
                    Node("q1.aw2", "q1.aw2", "q1.be1", (-225, 175)), Node("q1.aw1", "q2.ae2", "q1.aw1", (-225, 125)), Node("q1.as2", "q1.as2", "q1.bn1", (-225, 125)), Node("q1.as1", "q1.bn2", "q1.as1", (-275, 125)),
                    Node("q1.X", "q1.X", "q1.X", (200, 150)), Node("q1.Y", "q1.Y", "q1.Y", (200, -25)))
q1.__connectionBf__(Node("q1.be2", "q1.be2", "q1.Y", (-275, -50)), Node("q1.be1", "q1.aw2", "q1.be1", (-275, 0)), Node("q1.bn2", "q1.bn2", "q1.as1", (-275, 0)), Node("q1.bn1", "q1.as2", "q1.bn1", (-225, 0)),
                    Node("q1.bw2", "q1.bw2", "q2.be1", (-225, 0)), Node("q1.bw1", "q2.be2", "q1.bw1", (-225, -50)), Node("q1.bs2", "q1.bs2", "q1.sn1", (-225, -50)), Node("q1.bs1", "q1.sn2", "q1.bs1", (-275, -50)))
q1.__connectionSf__(Node("q1.se2", "q1.se2", "q1.se2", (-275, -225)), Node("q1.se1", "q1.an2", "q1.se1", (-275, -175)), Node("q1.sn2", "q1.sn2", "q1.bs1", (-275, -175)), Node("q1.sn1", "q1.bs2", "q1.sn1", (-225, -175)),
                    Node("q1.sw2", "q1.sw2", "q1.an1", (-225, -175)), Node("q1.sw1", "q1.se2", "q1.sw1", (-225, -225)), Node("q1.ss2", "q1.ss2", "q1.ss1", (-225, -225)), Node("q1.ss1", "q1.ss2", "q1.ss1", (-275, -225)))

q2.__connectionAf__(Node("q2.ae2", "q2.ae2", "q1.aw1", (-25, 125)), Node("q2.ae1", "q2.aw2", "q2.ae1", (-25, 175)), Node("q1.an2", "q2.an2", "q2.se1", (-25, 175)), Node("q2.an1", "q2.sw2", "q2.an1",(25, 175)),
                    Node("q2.aw2", "q2.aw2", "q2.ae1", (25, 175)), Node("q2.aw1", "q2.X", "q2.aw1", (25, 125)), Node("q2.as2", "q2.as2", "q2.bn1", (25, 125)), Node("q2.as1", "q2.bn2", "q2.as1", (-25, 125)),
                    Node("q2.X", "q2.X", "q2.X", (200, 150)), Node("q2.Y", "q2.Y", "q2.Y", (200, -25))) #again idk what to do for these
q2.__connectionBf__(Node("q2.be2", "q2.be2", "q1.bw1", (-25, -50)), Node("q2.be1", "q1.bw2", "q2.be1", (-25, 0)), Node("q2.bn2", "q2.bn2", "q2.as1", (-25, 0)), Node("q2.bn1", "q2.as2", "q2.bn1", (25, 0)),
                    Node("q2.bw2", "q2.bw2", "q1.ae1", (25, 0)), Node("q2.bw1", "q2.Y", "q2.bw1", (25, -50)), Node("q2.bs2", "q2.bs2", "q2.sn1", (25, -50)), Node("q2.bs1", "q2.sn2", "q2.bs1", (-25, -50)))
q2.__connectionSf__(Node("q2.se2", "q2.se2", "q2.se2", (-25, -225)), Node("q2.se1", "q2.an2", "a2.se1", (-25, -175)), Node("q2.sn2", "q2.sn2", "q2.bs1", (-25, -175)), Node("q2.sn1", "q2.bs2", "q2.sn1", (25, -175)),
                    Node("q2.sw2", "q2.sw2", "q2.an1", (25, -175)), Node("q2.sw1", "q2.se2", "q2.sw1", (25, -225)), Node("q2.ss2", "q2.ss2", "q2.ss1", (25, -225)), Node("q2.ss1", "q2.ss2", "q2.ss1", (-25, -225)))



classy = [q1, q2]
alpha = ["a", "b", "x", "y"]
out = []
token = (0, 0)
plot(classy, token)
direction = input("Forward(f) or Reverse(r): ")
if direction == "f":
    string = input("Enter a string of a's and b's to test: ")
elif direction == "r":
    string = input("Enter a string of x's and y's to test: ")
else:
    print("Invalid input")
    exit()
for l in list(string):
  if l not in alpha:
    print("Invalid input")
    exit()
end = 1
add = 'begin'
clear_output()
#loops/statements
if direction == "f":
    currentState = q1
    q1.s = 0
    for letter in list(string):
      finish = 1
      while finish:
          if end == 1:
              currentState = q1
              if letter == "a":
                  add = "ae2"
                  end = 0
                  plot(classy, (-275, 125))
              elif letter == "b":
                  add = "be2"
                  end = 0
                  plot(classy, (-275, -50))
              else:
                  print("That is an output for forward")
          else:
              if currentState.state+'.'+add == 'q1.ae2':
                  plot(classy, (-275, 125))
                  if q1.a == 1:
                      q1.a = 0
                      add = "as1"
                  else:
                      add = "aw1"
              elif currentState.state+'.'+add == 'q1.be2':
                  plot(classy, (-275, -50))
                  if q1.b == 1:
                      q1.b = 0
                      add = "bs1"
                  else:
                      add = "bw1"
              elif currentState.state+'.'+add == 'q1.se2':
                  plot(classy, (-275, -225))
                  if q1.s == 1:
                      q1.s = 0
                      add = "ss1"
                  else:
                      add = "sw1"
              elif currentState.state+'.'+add == 'q1.sw2':
                  plot(classy, (-225, -175))
                  if q1.s == 1:
                      q1.s = 0
                      add = "sn1"
                  else:
                      add = "se1"
              elif currentState.state+'.'+add == 'q1.bw2':
                  plot(classy, (-225, 0))
                  if q1.b == 1:
                      q1.b = 0
                      add = "bn1"
                  else:
                      add = "be1"
              elif currentState.state+'.'+add == 'q1.aw2':
                  plot(classy, (-225, 175))
                  if q1.a == 1:
                      q1.a = 0
                      add = "an1"
                  else:
                      add = "ae1"
              elif currentState.state+'.'+add == 'q1.an2':
                  plot(classy, (-275, 175))
                  if q1.a == 0:
                      q1.a = 1
                      add = "ae1"
                  else:
                      add = "as1"
              elif currentState.state+'.'+add == 'q1.bn2':
                  plot(classy, (-275, 0))
                  if q1.b == 0:
                      q1.b = 1
                      add = "be1"
                  else:
                      add = "bs1"
              elif currentState.state+'.'+add == 'q1.sn2':
                  plot(classy, (-275, -175))
                  if q1.s == 0:
                      q1.s = 1
                      add = "se1"
                  else:
                      add = "ss1"
              elif currentState.state+'.'+add == 'q1.ss2':
                  plot(classy, (-225, -225))
                  if q1.s == 0:
                      q1.s = 1
                      add = "sw1"
                  else:
                      add = "sn1"
              elif currentState.state+'.'+add == 'q1.bs2':
                  plot(classy, (-225, -50))
                  if q1.b == 0:
                      q1.b = 1
                      add = "bw1"
                  else:
                      add = "bn1"
              elif currentState.state+'.'+add == 'q1.as2':
                  plot(classy, (-225, 125))
                  if q1.a == 0:
                      q1.a = 1
                      add = "aw1"
                  else:
                      add = "an1"
              elif currentState.state+'.'+add == 'q2.ae2':
                  plot(classy, (-25, 125))
                  if q2.a == 1:
                      q2.a = 0
                      add = "as1"
                  else:
                      add = "aw1"
              elif currentState.state+'.'+add == 'q2.be2':
                  plot(classy, (-25, -50))
                  if q2.b == 1:
                      q2.b = 0
                      add = "bs1"
                  else:
                      add = "bw1"
              elif currentState.state+'.'+add == 'q2.se2':
                  plot(classy, (-25, -225))
                  if q2.s == 1:
                      q2.s = 0
                      add = "ss1"
                  else:
                      add = "sw1"
              elif currentState.state+'.'+add == 'q2.sw2':
                  plot(classy, (25, -225))
                  if q2.s == 1:
                      q2.s = 0
                      add = "sn1"
                  else:
                      add = "se1"
              elif currentState.state+'.'+add == 'q2.bw2':
                  plot(classy, (25, -50))
                  if q2.b == 1:
                      q2.b = 0
                      add = "bn1"
                  else:
                      add = "be1"
              elif currentState.state+'.'+add == 'q2.aw2':
                  plot(classy, (25, 175))
                  if q2.a == 1:
                      q2.a = 0
                      add = "an1"
                  else:
                      add = "ae1"
              elif currentState.state+'.'+add == 'q2.an2':
                  plot(classy, (-25, 175))
                  if q2.a == 0:
                      q2.a = 1
                      add = "ae1"
                  else:
                      add = "as1"
              elif currentState.state+'.'+add == 'q2.bn2':
                  plot(classy, (-25, 0))
                  if q2.b == 0:
                      q2.b = 1
                      add = "be1"
                  else:
                      add = "bs1"
              elif currentState.state+'.'+add == 'q2.sn2':
                  plot(classy, (-25, -175))
                  if q2.s == 0:
                      q2.s = 1
                      add = "se1"
                  else:
                      add = "ss1"
              elif currentState.state+'.'+add == 'q2.ss2':
                  plot(classy, (25, -225))
                  if q2.s == 0:
                      q2.s = 1
                      add = "sw1"
                  else:
                      add = "sn1"
              elif currentState.state+'.'+add == 'q2.bs2':
                  plot(classy, (25, -50))
                  if q2.b == 0:
                      q2.b = 1
                      add = "bw1"
                  else:
                      add = "bn1"
              elif currentState.state+'.'+add == 'q2.as2':
                  plot(classy, (25, 125))
                  if q2.a == 0:
                      q2.a = 1
                      add = "aw1"
                  else:
                      add = "an1"
              elif currentState.state+'.'+add == 'q2.X':
                  plot(classy, (200, 125))
                  end = 1
                  finish = 0
              elif currentState.state+'.'+add == 'q2.Y':
                  plot(classy, (200, -50))
                  end = 1
                  finish = 0
              else:
                  place = getattr(currentState, add)
                  plot(classy, place.io)
                  if place.name == 'q1.ae1' or place.name == 'q1.aw1' or place.name == 'q1.bw1':
                      currentState = q2
                  elif place.name == 'q2.be1':
                      currentState = q1
                  add = place.connect[3:6]
          pprint(currentState.state+'.'+add)
          time.sleep(2)
          if not end:
            clear_output()
      if currentState.state+'.'+add == 'q2.X':
            out.append("x")
      elif currentState.state+'.'+add == 'q2.Y':
            out.append("y")
  #time.sleep(1.5)
if direction == "r":
    currentState = q2
    q2.s = 0
    for letter in list(string):
        finish = 1
        while finish:
          if end == 1:
              if letter == "x":
                  currentState = q2
                  add = "aw1"
                  end = 0
                  plot(classy, (25, 175))
              elif letter == "y":
                  currentState = q2
                  add = "bw1"
                  end = 0
                  plot(classy, (25, 0))
              else:
                  print("That is an output for reverse")
          else:
              if currentState.state+'.'+add == 'q1.ae1':
                  plot(classy, (-275, 175))
                  if q1.a == 1:
                      q1.a = 0
                      add = "an2"
                  else:
                      q1.a = 1
                      add = "aw2"
              elif currentState.state+'.'+add == 'q1.be1':
                  plot(classy, (-275, 0))
                  if q1.b == 1:
                      q1.b = 0
                      add = "bn2"
                  else:
                      add = "bw2"
              elif currentState.state+'.'+add == 'q1.se1':
                  plot(classy, (-275, -175))
                  if q1.s == 1:
                      q1.s = 0
                      add = "sn2"
                  else:
                      add = "sw1"
              elif currentState.state+'.'+add == 'q1.sw1':
                  plot(classy, (-225, -225))
                  if q1.s == 1:
                      q1.s = 0
                      add = "ss2"
                  else:
                      add = "se1"
              elif currentState.state+'.'+add == 'q1.bw1':
                  plot(classy, (-225, -50))
                  if q1.b == 1:
                      q1.b = 0
                      add = "bs2"
                  else:
                      add = "be1"
              elif currentState.state+'.'+add == 'q1.aw1':
                  plot(classy, (-225, 125))
                  if q1.a == 1:
                      q1.a = 0
                      add = "as2"
                  else:
                      add = "ae1"
              elif currentState.state+'.'+add == 'q1.an1':
                  plot(classy, (-225, 175))
                  if q1.a == 0:
                      q1.a = 1
                      add = "aw2"
                  else:
                      add = "as2"
              elif currentState.state+'.'+add == 'q1.bn1':
                  plot(classy, (-225, 0))
                  if q1.b == 0:
                      q1.b = 1
                      add = "bw2"
                  else:
                      add = "bs2"
              elif currentState.state+'.'+add == 'q1.sn1':
                  plot(classy, (-225, -175))
                  if q1.s == 0:
                      q1.s = 1
                      add = "sw2"
                  else:
                      add = "ss2"
              elif currentState.state+'.'+add == 'q1.ss1':
                  plot(classy, (-275, -225))
                  if q1.s == 0:
                      q1.s = 1
                      add = "ss2"
                  else:
                      add = "sn2"
              elif currentState.state+'.'+add == 'q1.bs1':
                  plot(classy, (-275, -50))
                  if q1.b == 0:
                      q1.b = 1
                      add = "be2"
                  else:
                      add = "bn2"
              elif currentState.state+'.'+add == 'q1.as1':
                  plot(classy, (-275, 125))
                  if q1.a == 0:
                      q1.a = 1
                      add = "ae2"
                  else:
                      add = "an2"
              elif currentState.state+'.'+add == 'q2.ae1':
                  plot(classy, (-25, 175))
                  if q2.a == 1:
                      q2.a = 0
                      add = "an2"
                  else:
                      add = "aw2"
              elif currentState.state+'.'+add == 'q2.be1':
                  plot(classy, (-25, 0))
                  if q2.b == 1:
                      q2.b = 0
                      add = "bn2"
                  else:
                      add = "bw2"
              elif currentState.state+'.'+add == 'q2.se1':
                  plot(classy, (-25, -175))
                  if q2.s == 1:
                      q2.s = 0
                      add = "sn2"
                  else:
                      add = "sw2"
              elif currentState.state+'.'+add == 'q2.sw1':
                  plot(classy, (25, -225))
                  if q2.s == 1:
                      q2.s = 0
                      add = "ss2"
                  else:
                      add = "se2"
              elif currentState.state+'.'+add == 'q2.bw1':
                  plot(classy, (25, -50))
                  if q2.b == 1:
                      q2.b = 0
                      add = "bs2"
                  else:
                      add = "be2"
              elif currentState.state+'.'+add == 'q2.aw1':
                  plot(classy, (25, 125))
                  if q2.a == 1:
                      q2.a = 0
                      add = "as2"
                  else:
                      add = "ae2"
              elif currentState.state+'.'+add == 'q2.an1':
                  plot(classy, (25, 175))
                  if q2.a == 0:
                      q2.a = 1
                      add = "aw2"
                  else:
                      add = "as2"
              elif currentState.state+'.'+add == 'q2.bn1':
                  plot(classy, (25, 0))
                  if q2.b == 0:
                      q2.b = 1
                      add = "bw2"
                  else:
                      add = "bs2"
              elif currentState.state+'.'+add == 'q2.sn1':
                  plot(classy, (25, -175))
                  if q2.s == 0:
                      q2.s = 1
                      add = "sw2"
                  else:
                      add = "ss2"
              elif currentState.state+'.'+add == 'q2.ss1':
                  plot(classy, (-25, -225))
                  if q2.s == 0:
                      q2.s = 1
                      add = "se2"
                  else:
                      add = "sn2"
              elif currentState.state+'.'+add == 'q2.bs1':
                  plot(classy, (-25, -50))
                  if q2.b == 0:
                      q2.b = 1
                      add = "be2"
                  else:
                      add = "bn2"
              elif currentState.state+'.'+add == 'q2.as1':
                  plot(classy, (-25, 125))
                  if q2.a == 0:
                      q2.a = 1
                      add = "ae2"
                  else:
                      add = "an2"
              elif currentState.state+'.'+add == 'q1.X':
                  plot(classy, (-300, 125))
                  end = 1
                  finish = 0
              elif currentState.state+'.'+add == 'q1.Y':
                  plot(classy, (-300, -50))
                  end = 1
                  finish = 0
              else:
                  place = getattr(currentState, add)
                  plot(classy, place.io)
                  if place.name == 'q1.bw2':
                      currentState = q2
                  elif place.name == 'q2.bw2'  or place.name == 'q2.ae2' or place.name == 'q2.be2':
                      currentState = q1
                  add = place.connectr[3:6]
          pprint(currentState.state+'.'+add)
          time.sleep(2)
          if end != 1:
            clear_output()
        if currentState.state+'.'+add == 'q1.X':
            out.append("a")
        elif currentState.state+'.'+add == 'q1.Y':
            out.append("b")

print(*out)
if direction == 'f':
  if q1.s == 0:
    print("string accpeted")
  else:
    print("string not accepted")
# Out:
# 'q1.X'
# a b a a
